# %%
# %matplotlib inline
import os, shutil, warnings, string
import pandas as pd
import deepdish as dp
import numpy as np
import re
import fnmatch

# libs for plotting
import bokeh
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
from bokeh.models.tools import HoverTool
from bokeh.models import LinearColorMapper, ColorBar, BasicTicker, Select, PrintfTickFormatter
from bokeh.transform import jitter
from bokeh.sampledata.commits import data
from bokeh.palettes import brewer
import holoviews

# libs for stats
import time
from sklearn.manifold import TSNE

# print in notebok
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
datapath = '/Volumes/extreme/repos/lab-data/laser-experiments/'
folders_include    = ['oo-nir']
files_exclude      = ['.*','_*','*.asd','*.tcl','*.h5']
files_include      = ['*.txt']

columns = np.load('./columns.npy')

# %%
def read_nirdata(file,process_time = True, skiprows = 15):
    df = pd.read_csv(file, sep = '\t', skiprows = skiprows, header=None)
    dt = _get_nirdata_dt(file)
    if (df.shape[1]==2):
        df = df.T.copy()
    else:
        df = df.loc[:,2:].copy()
    df.columns = df.loc[0,:].apply(int)
    df.drop(index=0, inplace=True)
    df['dt'] = np.float64(dt)
    if process_time:
        df['rel_time'] = np.cumsum(df.loc[:,'dt'].values)
    return df

def _get_nirdata_dt(file):
    dt = pd.read_csv(file, sep = ':', skiprows=5, nrows=1).iloc[0,1]
    return dt

def _check_columns(df, columns, ix = -3):
    if not ((df.columns[0] == 898) and (df.columns[ix]==2560)):
        df.columns = columns
    return df

# %% [markdown]
# ## pre-process

# %%
dryrun = True
debug  = True
coerce_columns = True
excludes = r'|'.join([fnmatch.translate(x) for x in files_exclude]) or r'$.'
includes = r'|'.join([fnmatch.translate(x) for x in files_include]) or r'$.'
folders  = r'|'.join([fnmatch.translate(x) for x in folders_include]) or r'$.'
# df = pd.DataFrame(columns=['probe','sample-tag','subsample-tag','side','instance','fname','relroot'])

datadepth = len(datapath.split('/'))
dn = pd.DataFrame(columns=['exp-tag','sample-tag','subsample-tag','relroot'])
for root, dirs, files in os.walk(datapath, topdown=False):
    tags = {}
    # [dirs.remove(d) for d in list(dirs) if d not in folders_include]
    if len(re.findall(folders,root))==0:
        dirs[:]  = []
        files[:] = []
    else:
        files = [f for f in files if not re.match(excludes, f)]
        roots      = root.split('/')
        tags['exp-tag']    = root.split('/')[datadepth-1]
        tags['sample-tag'] = root.split('/')[datadepth]
        subornot = re.findall('subsample',root)
        if len(subornot)==1:
            subornot = subornot[0]
            tags['subsample-tag'] = root.split('/')[-2]
        else:
            tags['subsample-tag'] = ''
        
        flen = len(files)
        if flen>1:
            dfs = []
            for f in files:
                fname = os.path.join(root,f)
                df = read_nirdata(fname, process_time=False)
                df = _check_columns(df, columns[:-1], ix=-2)
                dfs.append(df)
            df = pd.concat(dfs, ignore_index=True)
            df['rel_time'] = np.cumsum(df.loc[:,'dt'].values)
        else:
            fname = os.path.join(root,files[0])
            df = read_nirdata(fname)
            df = _check_columns(df, columns)

        for key in ['exp','sample','subsample']:
            skey = key + '-tag'
            df[skey] = tags[skey]
        print(df.shape)
        sname = os.path.join(root,'oo-nir.h5')
        dp.io.save(sname,df)
        tags['relroot'] = os.path.relpath(os.path.join(root,sname),start=datapath)
        dn = dn.append(tags, ignore_index=True)
dn.sort_values(by=['exp-tag','sample-tag','subsample-tag'], inplace=True)
dn.reset_index(inplace=True, drop=True)
dn.to_csv('oo-nir-files-compiled.csv')

# %% [markdown]
# ## analytics

# %%
def _plot_tsne(tsne_results):
    if mapper is None:
         mapper = LinearColorMapper(palette='Viridis256', 
                           low=data.index.min(), high=data.index.max())

    p = figure(plot_width = 960, plot_height = 550)
    dtemp = pd.DataFrame({'x':tsne_results[:,0], 'y':tsne_results[:,1],'c':data.index.values})
    dtemp.head()
    p.scatter(x='x', y = 'y', source=dtemp, size=2, 
              color={'field': 'c', 'transform': mapper})
    show(p)
    
    return p 

def _tsne(df, N, n_components=2, save=True, outdir='./', savename='tsne-out', save_reduced_data=True):
    nrows = df.shape[0]
    if nrows<N:
        N = nrows
        
    df = df.sample(N).copy()
    
    time_start = time.time()
    tsne = TSNE(n_components=n_components, verbose=1, perplexity=40, n_iter=1000)
    tsne_results = tsne.fit_transform(df.values)
    print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
    
    out = pd.DataFrame(tsne_results)
    
    if save:
        dtout = {'tsne-results': out}
        if save_reduced_data:
            dtout['tsne-data'] = df
        for sfx in dtout.keys():
            savename = sfx + '-' + savename + '.h5'
            sname = os.path.join(outdir,savename)
            dp.io.save(sname, dtout[sfx])

    return out, df

def _gen_mapper(df):
    imax = df.loc[:,:].max().max()
    imin = df.loc[:,:].min().min()
    mapper = LinearColorMapper(palette='Viridis256', 
                           low=imin, high=imax)
    return mapper

# %%
descriptions = pd.read_csv('/sandbox/dev/lab-utils/oo-nir/oo-nir-files-compiled.csv')
descriptions.fillna('', inplace=True)

# %%
dfs = []
for i in range(0,descriptions.shape[0]):
    savename = '-'.join(descriptions.loc[i,['exp-tag','sample-tag','subsample-tag']].values)[:-1]
    r = descriptions.loc[i,'relroot']
    fname = os.path.join(datapath,r)
    df = dp.io.load(fname)
    df = df.iloc[:,:-5].copy()
    tsne_results,_ =  _tsne(df, 10000, save=True, n_components=3, outdir='./_out', savename=savename)
    del _
    for key in ['exp-tag','sample-tag','subsample-tag']:
        tsne_results[key] = descriptions.loc[i,key]
    dfs.append(tsne_results)
    print(savename, fname, sep='\n')

df = pd.concat(dfs,ignore_index=True)
dp.io.save('./_out/tsne-10000.h5',df)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.292s...
# [t-SNE] Computed neighbors for 10000 samples in 48.566s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 39.470736
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.433319
# [t-SNE] Error after 1000 iterations: 2.271963
# t-SNE done! Time elapsed: 550.631053686142 seconds
# cca-remedy-MSt-00005
# /Volumes/extreme/repos/lab-data/laser-experiments/cca-remedy/MSt-00005/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.257s...
# [t-SNE] Computed neighbors for 10000 samples in 87.429s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 29.404021
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 88.237213
# [t-SNE] Error after 850 iterations: 3.456746
# t-SNE done! Time elapsed: 591.833526134491 seconds
# fluid-transmission-H2Or-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/fluid-transmission/H2Or-00001/test-00-10082018/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.319s...
# [t-SNE] Computed neighbors for 10000 samples in 69.268s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 33.710058
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.779556
# [t-SNE] Error after 950 iterations: 2.816711
# t-SNE done! Time elapsed: 522.8377652168274 seconds
# fluid-transmission-H2Or-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/fluid-transmission/H2Or-00001/test-01-10242018/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.331s...
# [t-SNE] Computed neighbors for 10000 samples in 80.527s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 34.586914
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.325775
# [t-SNE] Error after 1000 iterations: 2.534020
# t-SNE done! Time elapsed: 528.247969865799 seconds
# fluid-transmission-H2Or-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/fluid-transmission/H2Or-00001/test-02-10252018/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.294s...
# [t-SNE] Computed neighbors for 10000 samples in 45.056s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 36.675944
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.097527
# [t-SNE] Error after 1000 iterations: 2.149831
# t-SNE done! Time elapsed: 513.2283270359039 seconds
# matrix-optimization-LSsy-00007
# /Volumes/extreme/repos/lab-data/laser-experiments/matrix-optimization/LSsy-00007/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.260s...
# [t-SNE] Computed neighbors for 10000 samples in 81.757s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 31.548814
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.376297
# [t-SNE] Error after 1000 iterations: 2.557936
# t-SNE done! Time elapsed: 681.3968470096588 seconds
# matrix-optimization-LSsy-00008
# /Volumes/extreme/repos/lab-data/laser-experiments/matrix-optimization/LSsy-00008/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.308s...
# [t-SNE] Computed neighbors for 10000 samples in 36.813s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 19.837070
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.733292
# [t-SNE] Error after 1000 iterations: 1.768213
# t-SNE done! Time elapsed: 471.8091652393341 seconds
# perforation-BG-00006
# /Volumes/extreme/repos/lab-data/laser-experiments/perforation/BG-00006/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.285s...
# [t-SNE] Computed neighbors for 10000 samples in 51.907s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 53.542236
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.737152
# [t-SNE] Error after 1000 iterations: 0.945960
# t-SNE done! Time elapsed: 415.80848002433777 seconds
# perforation-SH-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/perforation/SH-00001/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.310s...
# [t-SNE] Computed neighbors for 10000 samples in 21.798s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 32.236287
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.559204
# [t-SNE] Error after 1000 iterations: 1.440577
# t-SNE done! Time elapsed: 512.3303642272949 seconds
# scale-removal-ScCaCO-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScCaCO-00001/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.303s...
# [t-SNE] Computed neighbors for 10000 samples in 13.870s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 76.448148
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.661255
# [t-SNE] Error after 1000 iterations: 0.598160
# t-SNE done! Time elapsed: 391.8410360813141 seconds
# scale-removal-ScFeS-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00001/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.331s...
# [t-SNE] Computed neighbors for 10000 samples in 19.111s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 126.930487
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.052319
# [t-SNE] Error after 1000 iterations: 0.500735
# t-SNE done! Time elapsed: 345.4762659072876 seconds
# scale-removal-ScFeS-00002
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00002/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1098 samples in 0.010s...
# [t-SNE] Computed neighbors for 1098 samples in 0.442s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1098
# [t-SNE] Computed conditional probabilities for sample 1098 / 1098
# [t-SNE] Mean sigma: 334.368107
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.523129
# [t-SNE] Error after 1000 iterations: 0.172454
# t-SNE done! Time elapsed: 26.913100242614746 seconds
# scale-removal-ScFeS-00002-sample-0
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00002/_subsamples/sample-01/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 930 samples in 0.006s...
# [t-SNE] Computed neighbors for 930 samples in 0.594s...
# [t-SNE] Computed conditional probabilities for sample 930 / 930
# [t-SNE] Mean sigma: 217.250701
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.628288
# [t-SNE] Error after 1000 iterations: 0.185817
# t-SNE done! Time elapsed: 22.28290581703186 seconds
# scale-removal-ScFeS-00002-sample-0
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00002/_subsamples/sample-02/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 7056 samples in 0.179s...
# [t-SNE] Computed neighbors for 7056 samples in 30.942s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7056
# [t-SNE] Computed conditional probabilities for sample 2000 / 7056
# [t-SNE] Computed conditional probabilities for sample 3000 / 7056
# [t-SNE] Computed conditional probabilities for sample 4000 / 7056
# [t-SNE] Computed conditional probabilities for sample 5000 / 7056
# [t-SNE] Computed conditional probabilities for sample 6000 / 7056
# [t-SNE] Computed conditional probabilities for sample 7000 / 7056
# [t-SNE] Computed conditional probabilities for sample 7056 / 7056
# [t-SNE] Mean sigma: 228.469603
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.033337
# [t-SNE] Error after 1000 iterations: 0.319011
# t-SNE done! Time elapsed: 245.5092968940735 seconds
# scale-removal-ScFeS-00002-sample-0
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00002/_subsamples/sample-03/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.292s...
# [t-SNE] Computed neighbors for 10000 samples in 83.833s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 31.848919
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.935188
# [t-SNE] Error after 850 iterations: 3.103098
# t-SNE done! Time elapsed: 623.9698266983032 seconds
# underwater-perf-BG-00007
# /Volumes/extreme/repos/lab-data/laser-experiments/underwater-perf/BG-00007/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.319s...
# [t-SNE] Computed neighbors for 10000 samples in 17.515s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 47.300754
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.440483
# [t-SNE] Error after 1000 iterations: 1.353738
# t-SNE done! Time elapsed: 384.871062040329 seconds
# underwater-perf-LSsy-00013
# /Volumes/extreme/repos/lab-data/laser-experiments/underwater-perf/LSsy-00013/oo-nir/oo-nir.h5
# /sandbox/opt/share/anaconda/lib/python3.6/site-packages/deepdish/io/hdf5io.py:581: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   filters=filters, idtable=idtable)

# %%
dfs = []

descriptions['laser-on'] = True

def _log10(x):
    out = np.zeros(x.shape)
    out[x>0] = np.log10(x[x>0])
    out[x<=0] = 0
    return out

for i in range(0,descriptions.shape[0]):
    savename = '-'.join(descriptions.loc[i,['exp-tag','sample-tag','subsample-tag']].values)[:-1]
    savename = 'reduced-avg-' + savename
    
    r = descriptions.loc[i,'relroot']
    fname = os.path.join(datapath,r)
    df = dp.io.load(fname)
    df = df.iloc[:,:-5].copy()
    # seek the values above threshold (laser on)
    tindex = df.apply(np.average,axis=1).values>100
    df = df.iloc[tindex,:-5].copy()
    if df.shape[0]>0:
        # apply log10 to data
        df = df.apply(lambda x: _log10(x)).copy()

        tsne_results,_ =  _tsne(df, 10000, save=True, n_components=2, outdir='./_out', savename=savename)
        del _
        for key in ['exp-tag','sample-tag','subsample-tag']:
            tsne_results[key] = descriptions.loc[i,key]
        dfs.append(tsne_results)
        print(savename, fname, sep='\n')
    else:
        descriptions.loc[i,'laser-on'] = False

df = pd.concat(dfs,ignore_index=True)
dp.io.save('./_out/tsne-10000-reduced-avg-2.h5',df)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.213s...
# [t-SNE] Computed neighbors for 10000 samples in 49.878s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.074029
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.417229
# [t-SNE] Error after 1000 iterations: 2.444390
# t-SNE done! Time elapsed: 336.61972284317017 seconds
# reduced-avg-cca-remedy-MSt-00005
# /Volumes/extreme/repos/lab-data/laser-experiments/cca-remedy/MSt-00005/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 200 samples in 0.005s...
# [t-SNE] Computed neighbors for 200 samples in 0.020s...
# [t-SNE] Computed conditional probabilities for sample 200 / 200
# [t-SNE] Mean sigma: 1.783668
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.388832
# [t-SNE] Error after 1000 iterations: 0.776127
# t-SNE done! Time elapsed: 3.4588680267333984 seconds
# reduced-avg-fluid-transmission-H2Or-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/fluid-transmission/H2Or-00001/test-00-10082018/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 4217 samples in 0.059s...
# [t-SNE] Computed neighbors for 4217 samples in 15.101s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4217
# [t-SNE] Computed conditional probabilities for sample 2000 / 4217
# [t-SNE] Computed conditional probabilities for sample 3000 / 4217
# [t-SNE] Computed conditional probabilities for sample 4000 / 4217
# [t-SNE] Computed conditional probabilities for sample 4217 / 4217
# [t-SNE] Mean sigma: 1.553000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.997528
# [t-SNE] Error after 1000 iterations: 2.880445
# t-SNE done! Time elapsed: 124.92998003959656 seconds
# reduced-avg-fluid-transmission-H2Or-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/fluid-transmission/H2Or-00001/test-01-10242018/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 6113 samples in 0.121s...
# [t-SNE] Computed neighbors for 6113 samples in 30.475s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6113
# [t-SNE] Computed conditional probabilities for sample 2000 / 6113
# [t-SNE] Computed conditional probabilities for sample 3000 / 6113
# [t-SNE] Computed conditional probabilities for sample 4000 / 6113
# [t-SNE] Computed conditional probabilities for sample 5000 / 6113
# [t-SNE] Computed conditional probabilities for sample 6000 / 6113
# [t-SNE] Computed conditional probabilities for sample 6113 / 6113
# [t-SNE] Mean sigma: 1.356256
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.635330
# [t-SNE] Error after 1000 iterations: 3.061481
# t-SNE done! Time elapsed: 208.30972123146057 seconds
# reduced-avg-fluid-transmission-H2Or-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/fluid-transmission/H2Or-00001/test-02-10252018/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.216s...
# [t-SNE] Computed neighbors for 10000 samples in 36.469s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.031715
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.249908
# [t-SNE] Error after 1000 iterations: 1.650970
# t-SNE done! Time elapsed: 292.56143403053284 seconds
# reduced-avg-matrix-optimization-LSsy-00007
# /Volumes/extreme/repos/lab-data/laser-experiments/matrix-optimization/LSsy-00007/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.160s...
# [t-SNE] Computed neighbors for 10000 samples in 35.948s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.710636
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.926979
# [t-SNE] Error after 1000 iterations: 1.672633
# t-SNE done! Time elapsed: 274.7114248275757 seconds
# reduced-avg-matrix-optimization-LSsy-00008
# /Volumes/extreme/repos/lab-data/laser-experiments/matrix-optimization/LSsy-00008/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.218s...
# [t-SNE] Computed neighbors for 10000 samples in 57.242s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.300052
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.661606
# [t-SNE] Error after 1000 iterations: 1.902473
# t-SNE done! Time elapsed: 325.6993968486786 seconds
# reduced-avg-perforation-BG-00006
# /Volumes/extreme/repos/lab-data/laser-experiments/perforation/BG-00006/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 689 samples in 0.004s...
# [t-SNE] Computed neighbors for 689 samples in 0.317s...
# [t-SNE] Computed conditional probabilities for sample 689 / 689
# [t-SNE] Mean sigma: 1.108551
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.299431
# [t-SNE] Error after 1000 iterations: 0.749789
# t-SNE done! Time elapsed: 13.793858051300049 seconds
# reduced-avg-perforation-SH-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/perforation/SH-00001/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 475 samples in 0.002s...
# [t-SNE] Computed neighbors for 475 samples in 0.141s...
# [t-SNE] Computed conditional probabilities for sample 475 / 475
# [t-SNE] Mean sigma: 2.226801
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.159950
# [t-SNE] Error after 1000 iterations: 0.290528
# t-SNE done! Time elapsed: 9.624726057052612 seconds
# reduced-avg-scale-removal-ScCaCO-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScCaCO-00001/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.217s...
# [t-SNE] Computed neighbors for 10000 samples in 39.799s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.068658
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.838799
# [t-SNE] Error after 1000 iterations: 1.500588
# t-SNE done! Time elapsed: 332.83507108688354 seconds
# reduced-avg-scale-removal-ScFeS-00001
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00001/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 8546 samples in 0.181s...
# [t-SNE] Computed neighbors for 8546 samples in 57.320s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8546
# [t-SNE] Computed conditional probabilities for sample 2000 / 8546
# [t-SNE] Computed conditional probabilities for sample 3000 / 8546
# [t-SNE] Computed conditional probabilities for sample 4000 / 8546
# [t-SNE] Computed conditional probabilities for sample 5000 / 8546
# [t-SNE] Computed conditional probabilities for sample 6000 / 8546
# [t-SNE] Computed conditional probabilities for sample 7000 / 8546
# [t-SNE] Computed conditional probabilities for sample 8000 / 8546
# [t-SNE] Computed conditional probabilities for sample 8546 / 8546
# [t-SNE] Mean sigma: 1.071992
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.058937
# [t-SNE] Error after 1000 iterations: 1.324838
# t-SNE done! Time elapsed: 279.2142641544342 seconds
# reduced-avg-scale-removal-ScFeS-00002
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00002/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 672 samples in 0.004s...
# [t-SNE] Computed neighbors for 672 samples in 0.246s...
# [t-SNE] Computed conditional probabilities for sample 672 / 672
# [t-SNE] Mean sigma: 1.978231
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.706055
# [t-SNE] Error after 1000 iterations: 0.379530
# t-SNE done! Time elapsed: 11.747442960739136 seconds
# reduced-avg-scale-removal-ScFeS-00002-sample-0
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00002/_subsamples/sample-01/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 979 samples in 0.009s...
# [t-SNE] Computed neighbors for 979 samples in 0.816s...
# [t-SNE] Computed conditional probabilities for sample 979 / 979
# [t-SNE] Mean sigma: 1.987038
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.550636
# [t-SNE] Error after 1000 iterations: 0.487874
# t-SNE done! Time elapsed: 19.42069911956787 seconds
# reduced-avg-scale-removal-ScFeS-00002-sample-0
# /Volumes/extreme/repos/lab-data/laser-experiments/scale-removal/ScFeS-00002/_subsamples/sample-03/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 6203 samples in 0.121s...
# [t-SNE] Computed neighbors for 6203 samples in 33.450s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6203
# [t-SNE] Computed conditional probabilities for sample 2000 / 6203
# [t-SNE] Computed conditional probabilities for sample 3000 / 6203
# [t-SNE] Computed conditional probabilities for sample 4000 / 6203
# [t-SNE] Computed conditional probabilities for sample 5000 / 6203
# [t-SNE] Computed conditional probabilities for sample 6000 / 6203
# [t-SNE] Computed conditional probabilities for sample 6203 / 6203
# [t-SNE] Mean sigma: 1.711963
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.695595
# [t-SNE] Error after 1000 iterations: 2.144419
# t-SNE done! Time elapsed: 188.45709490776062 seconds
# reduced-avg-underwater-perf-BG-00007
# /Volumes/extreme/repos/lab-data/laser-experiments/underwater-perf/BG-00007/oo-nir/oo-nir.h5
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.232s...
# [t-SNE] Computed neighbors for 10000 samples in 74.849s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.684280
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.216011
# [t-SNE] Error after 1000 iterations: 2.414206
# t-SNE done! Time elapsed: 390.1546280384064 seconds
# reduced-avg-underwater-perf-LSsy-00013
# /Volumes/extreme/repos/lab-data/laser-experiments/underwater-perf/LSsy-00013/oo-nir/oo-nir.h5
# /sandbox/opt/share/anaconda/lib/python3.6/site-packages/deepdish/io/hdf5io.py:581: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   filters=filters, idtable=idtable)

# %%
df = dp.io.load(fname)
df = df.iloc[:,:-5].copy()
# seek the values above threshold (laser on)
tindex = df.apply(np.average,axis=1).values>50
df = df.iloc[tindex,:-5].copy()

# %%
df.shape[0]>0
# Out:
# False

# %%
descriptions.loc[i,'laser-on'] = False

# %%
for key in ['exp-tag','sample-tag','subsample-tag']:
    df[key] = descriptions.loc[i,key]

# %%
tsne_results,_ =  _tsne(df, 100, save=True, n_components=3, outdir='./_out', savename=savename)
del _
# Out:
# [t-SNE] Computing 99 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 203.886620
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.415367
# [t-SNE] Error after 1000 iterations: 1.287474
# t-SNE done! Time elapsed: 1.5822548866271973 seconds

# %%
for key in ['exp-tag','sample-tag','subsample-tag']:
    tsne_results[key] = descriptions.loc[i,key]
dfs.append(tsne_results)
print(savename, fname, sep='\n')
# Out:
# cca-remedy-MSt-00005
# /Volumes/extreme/repos/lab-data/laser-experiments/cca-remedy/MSt-00005/oo-nir/oo-nir.h5

# %%
dfs
# Out:
# [             0           1           2     exp-tag sample-tag subsample-tag
#  0   -57.486706  -27.467167 -123.752319  cca-remedy  MSt-00005
#  1     5.583789   45.571819 -112.640793  cca-remedy  MSt-00005
#  2   157.966751 -120.225006  106.597809  cca-remedy  MSt-00005
#  3   -87.501167 -112.429489  -41.193211  cca-remedy  MSt-00005
#  4  -116.298653  -60.556286   90.623199  cca-remedy  MSt-00005
#  5  -147.398575  -66.437904  -68.440941  cca-remedy  MSt-00005
#  6   -75.179298  141.438416 -106.696106  cca-remedy  MSt-00005
#  7    47.320713  -81.261490   84.402443  cca-remedy  MSt-00005
#  8    14.794386  -11.858595 -200.777603  cca-remedy  MSt-00005
#  9    45.218800  -81.464317  -29.106478  cca-remedy  MSt-00005
#  10  124.375504 -133.048721    7.193214  cca-remedy  MSt-00005
#  11  143.568130  -18.430649 -143.529221  cca-remedy  MSt-00005
#  12   57.613304  -16.795727  184.650391  cca-remedy  MSt-00005
#  13  -26.202782   67.473312   -3.981629  cca-remedy  MSt-00005
#  14   -0.352522   97.099602  -64.329773  cca-remedy  MSt-00005
#  15  -73.896759  123.891327  -11.066064  cca-remedy  MSt-00005
#  16  -20.399626  178.455688  -51.324741  cca-remedy  MSt-00005
#  17   96.579323    9.867987  108.902550  cca-remedy  MSt-00005
#  18  -48.292419  -75.137291   15.371924  cca-remedy  MSt-00005
#  19  183.339828   21.263853    2.636393  cca-remedy  MSt-00005
#  20 -146.638107   21.554356   37.596786  cca-remedy  MSt-00005
#  21   77.155075  -23.119833   54.368408  cca-remedy  MSt-00005
#  22  -11.303237  -65.499451   76.326141  cca-remedy  MSt-00005
#  23  111.043045 -159.961517  -14.558847  cca-remedy  MSt-00005
#  24 -127.530380   92.971970   23.521572  cca-remedy  MSt-00005
#  25 -174.813965   85.136116  -35.960979  cca-remedy  MSt-00005
#  26  164.850342 -105.023010   -5.390374  cca-remedy  MSt-00005
#  27   28.363085   26.566090  -56.563931  cca-remedy  MSt-00005
#  28 -127.087883   50.604607  -74.010040  cca-remedy  MSt-00005
#  29 -112.127625  -34.536472  -12.808355  cca-remedy  MSt-00005
#  ..         ...         ...         ...         ...        ...           ...
#  70 -128.010269  121.737831  -67.827858  cca-remedy  MSt-00005
#  71  -15.024994  118.077621 -168.575760  cca-remedy  MSt-00005
#  72   20.738657 -184.445450    9.296418  cca-remedy  MSt-00005
#  73   64.036392  128.590118  112.267601  cca-remedy  MSt-00005
#  74  -69.801544   70.732552  130.741562  cca-remedy  MSt-00005
#  75    8.493442 -130.737411  -96.705215  cca-remedy  MSt-00005
#  76  -56.268692   69.602196  -56.542282  cca-remedy  MSt-00005
#  77  -26.116831  132.439941  106.835304  cca-remedy  MSt-00005
#  78  -32.739891  -48.341309  -47.862450  cca-remedy  MSt-00005
#  79 -104.646011   32.131004  -16.678705  cca-remedy  MSt-00005
#  80   17.110252   19.097647   10.053881  cca-remedy  MSt-00005
#  81  -31.220583   12.493738  -52.417629  cca-remedy  MSt-00005
#  82   39.628841   78.207977   -4.500477  cca-remedy  MSt-00005
#  83  111.040451   29.140915   47.353779  cca-remedy  MSt-00005
#  84   71.762100 -119.189110  138.029617  cca-remedy  MSt-00005
#  85   17.134201  -69.351456  141.683685  cca-remedy  MSt-00005
#  86  -65.754684 -107.420944  104.304222  cca-remedy  MSt-00005
#  87   42.828880  147.356964 -101.510902  cca-remedy  MSt-00005
#  88 -112.311668  185.408554   -1.713814  cca-remedy  MSt-00005
#  89  107.787842  105.607590   76.258911  cca-remedy  MSt-00005
#  90   -9.886244 -134.213501  -18.501463  cca-remedy  MSt-00005
#  91 -186.619888  -57.617085   -8.624135  cca-remedy  MSt-00005
#  92   38.520420  -15.601969  102.067093  cca-remedy  MSt-00005
#  93  -93.776031 -145.740112   31.592762  cca-remedy  MSt-00005
#  94   74.098923   86.005424 -160.346436  cca-remedy  MSt-00005
#  95   80.572456   29.575457  -19.524355  cca-remedy  MSt-00005
#  96 -117.376511   67.894493   82.105103  cca-remedy  MSt-00005
#  97 -123.836937   10.462979  117.519417  cca-remedy  MSt-00005
#  98  -61.420475   59.854694 -117.735596  cca-remedy  MSt-00005
#  99   83.758659  -23.298452  -78.347954  cca-remedy  MSt-00005
#
#  [100 rows x 6 columns]]
